# %%
import tweepy
import csv
import json

# %%
"""
Consumer API keys
v5s7PGBedDnzBKCNJxm4EWYg6 (API key)

guxK7N5rAakh5jgPHG0M7mEtk1I92GLp4oC8RoKGZb3j7B1IEv (API secret key)

Access token & access token secret
749843357740855296-DN4SqhRj6FcqOlpAEFzJ2S8TuUcDjKH (Access token)

yoAnxRxexPrRL5ZFuKDK9y86PdfGbWbgq0Cxpe9rdb1m7 (Access token secret)

Read and write (Access level)
"""
# Out:
# '\nConsumer API keys\nv5s7PGBedDnzBKCNJxm4EWYg6 (API key)\n\nguxK7N5rAakh5jgPHG0M7mEtk1I92GLp4oC8RoKGZb3j7B1IEv (API secret key)\n\nAccess token & access token secret\n749843357740855296-DN4SqhRj6FcqOlpAEFzJ2S8TuUcDjKH (Access token)\n\nyoAnxRxexPrRL5ZFuKDK9y86PdfGbWbgq0Cxpe9rdb1m7 (Access token secret)\n\nRead and write (Access level)\n'

# %%
consumer_key = 'v5s7PGBedDnzBKCNJxm4EWYg6'
consumer_secret = 'guxK7N5rAakh5jgPHG0M7mEtk1I92GLp4oC8RoKGZb3j7B1IEv'

access_token = '749843357740855296-DN4SqhRj6FcqOlpAEFzJ2S8TuUcDjKH'
access_token_secret = 'yoAnxRxexPrRL5ZFuKDK9y86PdfGbWbgq0Cxpe9rdb1m7'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
fetch_tweets = tweepy.Cursor(api.search, q = 'mcdonalds').items(100)
for i in fetch_tweets:
    print('-------')
    j = i._json
    #print(json.dumps(j, indent=4))
    print(i.geo)
    print(i.lang)
    print('~~~~~~~')
# Out:
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# und
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# pt
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# fr
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# fr
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# fr
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# und
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# tr
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# ja
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# es
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# tr
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~
# -------
# None
# en
# ~~~~~~~

# %%
fetch_tweets = tweepy.Cursor(api.search, q = 'mcdonalds').items(100)
for i in fetch_tweets:
    print('-------')
    j = i._json
    #print(json.dumps(j, indent=4))
    print(i.geo)
    print(i.lang)
    print('~~~~~~~')

# %% [markdown]
# {
#     "created_at": "Fri Oct 26 22:40:10 +0000 2018",
#     "id": 1055952252496564224,
#     "id_str": "1055952252496564224",
#     "text": "@McDonalds the customer service at your Clackamas, OR store is terrible.",
#     "truncated": false,
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [
#             {
#                 "screen_name": "McDonalds",
#                 "name": "McDonald's",
#                 "id": 71026122,
#                 "id_str": "71026122",
#                 "indices": [
#                     0,
#                     10
#                 ]
#             }
#         ],
#         "urls": []
#     },
#     "metadata": {
#         "iso_language_code": "en",
#         "result_type": "recent"
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": 71026122,
#     "in_reply_to_user_id_str": "71026122",
#     "in_reply_to_screen_name": "McDonalds",
#     "user": {
#         "id": 30165863,
#         "id_str": "30165863",
#         "name": "Tyler Matney",
#         "screen_name": "tylermatney",
#         "location": "",
#         "description": "Registered Nurse, BSN, Avgeek. I try my best to make the world a better place.",
#         "url": "http://t.co/FXWhIfZJr7",
#         "entities": {
#             "url": {
#                 "urls": [
#                     {
#                         "url": "http://t.co/FXWhIfZJr7",
#                         "expanded_url": "http://www.facebook.com/tylermatney",
#                         "display_url": "facebook.com/tylermatney",
#                         "indices": [
#                             0,
#                             22
#                         ]
#                     }
#                 ]
#             },
#             "description": {
#                 "urls": []
#             }
#         },
#         "protected": false,
#         "followers_count": 64,
#         "friends_count": 36,
#         "listed_count": 4,
#         "created_at": "Fri Apr 10 05:01:23 +0000 2009",
#         "favourites_count": 1182,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": false,
#         "verified": false,
#         "statuses_count": 4411,
#         "lang": "en",
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "ACDED6",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/452946941169516544/WHlNp0cg_normal.jpeg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/452946941169516544/WHlNp0cg_normal.jpeg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/30165863/1364715951",
#         "profile_link_color": "038543",
#         "profile_sidebar_border_color": "EEEEEE",
#         "profile_sidebar_fill_color": "F6F6F6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": false,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none"
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
# }

# %%
fetch_tweets = tweepy.Cursor(api.search, q = "mcdonalds" or "mcdonald's",lang = 'en').items(10)
with open('mc.csv', mode = 'w', newline='',encoding='UTF-8') as my_file:
    my_writer = csv.writer(my_file,delimiter=',')
    my_writer.writerow(['id',
                        'text',
                        'source',
                        'reply_screen_name',
                        'user_id',
                        'user_screen_name',
                       'user_location',
                        'followers_count',
                       'friends_count',
                        'listed_count',
                        'user_created_at',
                       'fav_counts',
                        'verified',
                        'user_lang',
                        'retweet_count',
                        'favorite_count',
                        'lang'])
    for i in fetch_tweets:
        my_writer.writerow([i.id,
                            i.text,
                           i.source,
                            i.in_reply_to_screen_name,
                           i.user.id,
                            i.user.screen_name,
                           i.user.location,
                           i.user.followers_count,
                            i.user.friends_count,
                           i.user.listed_count,
                            i.user.created_at,
                            i.user.favourites_count,
                           i.user.verified,
                           i.user.lang,
                           i.retweet_count,
                            i.favorite_count,
                           i.lang])

# %%
with open('mc.csv',mode = 'r',encoding ='UTF-8') as my_file:
    csv_reader = csv.reader(my_file,delimiter=',')
    line_count = 0
    for row in csv_reader:
        print('-----')
        print(row[0])
        print(row[1])
        print(row[2])
        print(row[3])
        print(row[4])
        print(row[5])
        print('-----')
# Out:
# -----
# id
# text
# source
# reply_screen_name
# user_id
# user_screen_name
# -----
# -----
# 1056319766518915073
# I entered to win @ McDonalds prize pack on @ mommysblckparty! #ad #mcdonalds  https://t.co/fYy5DMq61R https://t.co/KiY9eVOP7p
# Twitter Web Client
#
# 350446219
# cshell202
# -----
# -----
# 1056319722520801280
# Dear @McDonalds you have RUINED the apple pies. Change them back now! These new pies suck! Ps. Bring back HI-C, what’s wrong with you?
# Twitter for iPhone
#
# 30427135
# TastyTweets2147
# -----
# -----
# 1056319716640350211
# RT @fatbuIly: the mcdonalds drive tru vs chick fil a  https://t.co/GR3DKVztyD
# Twitter for iPhone
#
# 704229200
# KevoMorelli
# -----
# -----
# 1056319665037864961
# Dog Pretends To Be Stray And Scams People At McDonald's https://t.co/vYQZsFmsrk #dogs #McDonalds https://t.co/6u3VVOMrhe
# Buffer
#
# 306617794
# SocialNewsDaily
# -----
# -----
# 1056319643118456835
# RT @IamAkademiks: Imagine taking mcdonalds orders from G herbo, Chief Keef, Trippie Redd n Kodak Black 😂😂 https://t.co/VwcejiB5wq
# Twitter for iPhone
#
# 4355531362
# citgodasavage
# -----
# -----
# 1056319613783265280
# McDonalds should have a 3rd window, where you can trade in all the wrong shit they gave you at the second window...
# fbhsdfjhsadjfja
#
# 253005763
# ItsGuyThingss
# -----
# -----
# 1056319569411932160
# @DamnYouHenne @Interior @NPSGWMP Oh my, Teddy would be so pleased that obese people can now take the shortest route… https://t.co/EHFFGHbDZp
# Twitter for Android
# DamnYouHenne
# 974619988282789888
# ZinkesHorse
# -----
# -----
# 1056319522637037568
# I liked a @YouTube video https://t.co/o4zbgEIxOj MUPPET BABIES McDonalds Happy Meal Toys Full Set
# Google
#
# 189721777
# lillieeve
# -----
# -----
# 1056319514848174083
# RT @IamAkademiks: Imagine taking mcdonalds orders from G herbo, Chief Keef, Trippie Redd n Kodak Black 😂😂 https://t.co/VwcejiB5wq
# Twitter for iPhone
#
# 924122526
# _clarissat
# -----
# -----
# 1056319503339008001
# this is the mcdonalds worker everytime i go up to the counter and ask for the little packets of ketchup u get https://t.co/uiCycytDy1
# Twitter Web Client
# persona2ep
# 806971632728371205
# persona2ep
# -----

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to /Users/huangyan/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
from textblob import TextBlob
text1 = '11/1(木)から #マクドナルドx楽天スーパーコラボ キャンペーン2018スタート🎉あのコラボガチャが帰ってくる⁉11月まで待ちきれな～い😆というみなさんはこのツイートをRT！🔃 #お買いものパンダ とコラボした超レアなマックカードを抽…'
text = 'i am happy'
blob = TextBlob(text)
blob.tags
blob.noun_phrases
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)


#TextBlob('happy').polarity
# Out:
# 0.8

# %%
blob.translate(to="en")
# Out:
# ---------------------------------------------------------------------------
# NotTranslated                             Traceback (most recent call last)
# <ipython-input-62-13e2f0b2754b> in <module>()
# ----> 1 blob.translate(to="en")
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/textblob/blob.py in translate(self, from_lang, to)
#     539         """
#     540         return self.__class__(self.translator.translate(self.raw,
# --> 541                               from_lang=from_lang, to_lang=to))
#     542
#     543     def detect_language(self):
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/textblob/translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      59             except IndexError:
#      60                 pass
# ---> 61         self._validate_translation(source, result)
#      62         return result
#      63
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/textblob/translate.py in _validate_translation(self, source, result)
#      83             result = result.encode('utf-8')
#      84         if result.strip() == source.strip():
# ---> 85             raise NotTranslated('Translation API returned the input string unchanged.')
#      86
#      87     def _request(self, url, host=None, type_=None, data=None):
#
# NotTranslated: Translation API returned the input string unchanged.

# %%
fetch_tweets2 = tweepy.Cursor(api.search, q = 'mcdonalds',geocode = '34.052235,-118.243683,100km').items(10)
with open('mc2.csv', mode = 'w', newline='',encoding='UTF-8') as my_file:
    my_writer = csv.writer(my_file,delimiter=',')
    my_writer.writerow(['created_at','text','hashtags','symbols','source',
                        'reply_screen_name','user_id','user_screen_name',
                       'user_location','user_description','followers_count',
                       'friends_count','listed_count','user_created_at',
                       'verified','user_lang','is_translator',
                        'retweet_count','favorite_count','lang'])
    for i in fetch_tweets2:
        my_writer.writerow([i.created_at,i.text,i.entities['hashtags'],
                           i.entities['symbols'],
                           i.source,i.in_reply_to_screen_name,
                           i.user.id,i.user.screen_name,
                           i.user.location,i.user.description,
                           i.user.followers_count,i.user.friends_count,
                           i.user.listed_count,i.user.created_at,i.user.verified,
                           i.user.lang,i.user.is_translator,
                           i.retweet_count,i.favorite_count,
                           i.lang])

# %%
with open('mc.csv',mode = 'r',encoding ='UTF-8') as my_file:
    csv_reader = csv.reader(my_file,delimiter=',')
    line_count = 0
    for row in csv_reader:
        print('-----')
        print(row[0])
        print(row[1])
        print(row[2])
        print(row[3])
        print(row[4])
        print(row[5])
        print('-----')
